# %% [markdown]
# <a href="https://colab.research.google.com/github/marudengi/Practice_for_coding_test/blob/main/%EA%B1%B0%EC%8A%A4%EB%A6%84%EB%8F%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = 3270
count = 0

coins = [500,100,50,10]

for i in coins:
  count += N//i
  N %= i

print(count)
# Out:
# 11
